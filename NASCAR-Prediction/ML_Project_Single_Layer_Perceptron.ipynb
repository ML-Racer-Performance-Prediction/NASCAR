# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
def marginOfError(model, X_test, X_train, y_test, y_train):
    test_pred = model.predict(X_test)
    train_pred = model.predict(X_train)

    testCounts = getErrorMargins(y_test, test_pred)
    trainCounts = getErrorMargins(y_train, train_pred)

    plt.figure()
    plt.plot(range(30), testCounts, label="Testing Set")
    plt.plot(range(30), trainCounts, label="Training Set")
    plt.title("Final Position Margin of Error")
    plt.xlabel("Margin of Error (Positions)")
    plt.ylabel("Proportion Correct")
    plt.xlim(0, 30)
    plt.ylim(0, 1)
    plt.legend(loc='best')
    plt.show()

# %%
def getErrorMargins(y_actual, y_pred):
    y = y_actual.values.astype(float)
    counts = np.zeros(30)
    total = len(y)

    diff = np.zeros(total)
    for index in range(total):
        temp = abs(y[index] - y_pred[index])
        diff[index] = abs(y[index] - y_pred[index])

    for val in diff:
        for index in range(len(counts)):
            if val < index:
                counts[index] += 1

    x = sum(diff) / total
    counts = counts / total
    return counts

# %%
#Loads the dataset from github
data = pd.read_csv("https://raw.githubusercontent.com/ML-Racer-Performance-Prediction/NASCAR/main/Documentation/NASCAR%20Full%20Stats%20(2).csv")

# Separates the features and target
X = data.drop('EndingPosition', axis=1)
Y = data['EndingPosition']

# Features
categorical_cols = ['Track', 'Driver', 'Sponsor', 'Owner', 'CarManufacturer', 'TrackType']
numerical_cols = ['StartingPosition', 'CarNumber']

# Splits the dataset. 20% for testing
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=18)

# One-hot encoding the categorical features
categorical_transformer = OneHotEncoder(handle_unknown='ignore')
X_train_categorical = categorical_transformer.fit_transform(X_train[categorical_cols]).toarray()
X_test_categorical = categorical_transformer.transform(X_test[categorical_cols]).toarray()

# Feature scaling the numerical features
numerical_transformer = StandardScaler()
X_train_numerical = numerical_transformer.fit_transform(X_train[numerical_cols])
X_test_numerical = numerical_transformer.transform(X_test[numerical_cols])

# Combining the categorical and numerical features back together
X_train_combined = np.concatenate([X_train_categorical, X_train_numerical], axis=1)
X_test_combined = np.concatenate([X_test_categorical, X_test_numerical], axis=1)

# Builds the single layer perceptron model.
SLP = Sequential([
    Dense(1, activation='linear', input_shape=(X_train_combined.shape[1],)),
])

# Compiles the model with SGD, lr of 0.001, and a momentum of 0.8
optimizer = SGD(learning_rate=0.001, momentum=0.8)
SLP.compile(optimizer=optimizer, loss='mae', metrics=['mae'])

# Early stopping to prevent overfitting
stop_early = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Training the model with a batch size of 32 and maximum of 100 epochs
history = SLP.fit(X_train_combined, y_train, epochs=100, batch_size=32, validation_data=(X_test_combined, y_test), callbacks=[stop_early])

# Gets the loss histories
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_mae = history.history['mae']
val_mae = history.history['val_mae']

# Evaluates the model on the test set
test_loss = SLP.evaluate(X_test_combined, y_test, verbose=0)
print(f'Test MAE: {test_loss}')

# Makes predictions
y_pred = SLP.predict(X_test_combined)

# Calculates MAE, MSE, and R-squared, then prints results
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'Mean Absolute Error: {mae}')
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')

# Plots the training and validation loss
plt.figure()
plt.plot(range(1, len(train_loss) + 1), train_loss, label='Training Loss')
plt.plot(range(1, len(val_loss) + 1), val_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plots the training and validation MAE
plt.figure()
plt.plot(range(1, len(train_mae) + 1), train_mae, label='Training MAE')
plt.plot(range(1, len(val_mae) + 1), val_mae, label='Validation MAE')
plt.title('Training and Validation MAE')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()
plt.show()

marginOfError(SLP, X_test_combined, X_train_combined, y_test, y_train)
# Out:
# Epoch 1/100
# 136/136 [==============================] - 1s 4ms/step - loss: 18.8673 - mae: 18.8673 - val_loss: 17.8256 - val_mae: 17.8256
# Epoch 2/100
# 136/136 [==============================] - 0s 3ms/step - loss: 17.5866 - mae: 17.5866 - val_loss: 16.6578 - val_mae: 16.6578
# Epoch 3/100
# 136/136 [==============================] - 0s 3ms/step - loss: 16.4637 - mae: 16.4637 - val_loss: 15.6336 - val_mae: 15.6336
# Epoch 4/100
# 136/136 [==============================] - 0s 3ms/step - loss: 15.4774 - mae: 15.4774 - val_loss: 14.7425 - val_mae: 14.7425
# Epoch 5/100
# 136/136 [==============================] - 0s 3ms/step - loss: 14.6064 - mae: 14.6064 - val_loss: 13.9502 - val_mae: 13.9502
# Epoch 6/100
# 136/136 [==============================] - 0s 3ms/step - loss: 13.8259 - mae: 13.8259 - val_loss: 13.2464 - val_mae: 13.2464
# Epoch 7/100
# 136/136 [==============================] - 0s 3ms/step - loss: 13.1340 - mae: 13.1340 - val_loss: 12.6260 - val_mae: 12.6260
# Epoch 8/100
# 136/136 [==============================] - 0s 3ms/step - loss: 12.5283 - mae: 12.5283 - val_loss: 12.0849 - val_mae: 12.0849
# Epoch 9/100
# 136/136 [==============================] - 0s 3ms/step - loss: 11.9934 - mae: 11.9934 - val_loss: 11.5998 - val_mae: 11.5998
# Epoch 10/100
# 136/136 [==============================] - 0s 3ms/step - loss: 11.5171 - mae: 11.5171 - val_loss: 11.1681 - val_mae: 11.1681
# Epoch 11/100
# 136/136 [==============================] - 1s 4ms/step - loss: 11.0896 - mae: 11.0896 - val_loss: 10.7697 - val_mae: 10.7697
# Epoch 12/100
# 136/136 [==============================] - 1s 5ms/step - loss: 10.7042 - mae: 10.7042 - val_loss: 10.4059 - val_mae: 10.4059
# Epoch 13/100
# 136/136 [==============================] - 1s 5ms/step - loss: 10.3577 - mae: 10.3577 - val_loss: 10.0841 - val_mae: 10.0841
# Epoch 14/100
# 136/136 [==============================] - 1s 4ms/step - loss: 10.0534 - mae: 10.0534 - val_loss: 9.7944 - val_mae: 9.7944
# Epoch 15/100
# 136/136 [==============================] - 1s 4ms/step - loss: 9.7854 - mae: 9.7854 - val_loss: 9.5424 - val_mae: 9.5424
# Epoch 16/100
# 136/136 [==============================] - 0s 3ms/step - loss: 9.5501 - mae: 9.5501 - val_loss: 9.3247 - val_mae: 9.3247
# Epoch 17/100
# 136/136 [==============================] - 0s 3ms/step - loss: 9.3409 - mae: 9.3409 - val_loss: 9.1285 - val_mae: 9.1285
# Epoch 18/100
# 136/136 [==============================] - 0s 3ms/step - loss: 9.1595 - mae: 9.1595 - val_loss: 8.9584 - val_mae: 8.9584
# Epoch 19/100
# 136/136 [==============================] - 0s 3ms/step - loss: 8.9992 - mae: 8.9992 - val_loss: 8.8025 - val_mae: 8.8025
# Epoch 20/100
# 136/136 [==============================] - 0s 3ms/step - loss: 8.8528 - mae: 8.8528 - val_loss: 8.6622 - val_mae: 8.6622
# Epoch 21/100
# 136/136 [==============================] - 0s 3ms/step - loss: 8.7216 - mae: 8.7216 - val_loss: 8.5399 - val_mae: 8.5399
# Epoch 22/100
# 136/136 [==============================] - 0s 3ms/step - loss: 8.6090 - mae: 8.6090 - val_loss: 8.4327 - val_mae: 8.4327
# Epoch 23/100
# 136/136 [==============================] - 0s 3ms/step - loss: 8.5102 - mae: 8.5102 - val_loss: 8.3396 - val_mae: 8.3396
# Epoch 24/100
# 136/136 [==============================] - 0s 3ms/step - loss: 8.4248 - mae: 8.4248 - val_loss: 8.2595 - val_mae: 8.2595
# Epoch 25/100
# 136/136 [==============================] - 0s 3ms/step - loss: 8.3504 - mae: 8.3504 - val_loss: 8.1894 - val_mae: 8.1894
# Epoch 26/100
# 136/136 [==============================] - 0s 3ms/step - loss: 8.2838 - mae: 8.2838 - val_loss: 8.1266 - val_mae: 8.1266
# Epoch 27/100
# 136/136 [==============================] - 0s 3ms/step - loss: 8.2249 - mae: 8.2249 - val_loss: 8.0727 - val_mae: 8.0727
# Epoch 28/100
# 136/136 [==============================] - 0s 3ms/step - loss: 8.1728 - mae: 8.1728 - val_loss: 8.0250 - val_mae: 8.0250
# Epoch 29/100
# 136/136 [==============================] - 0s 3ms/step - loss: 8.1284 - mae: 8.1284 - val_loss: 7.9850 - val_mae: 7.9850
# Epoch 30/100
# 136/136 [==============================] - 0s 3ms/step - loss: 8.0909 - mae: 8.0909 - val_loss: 7.9508 - val_mae: 7.9508
# Epoch 31/100
# 136/136 [==============================] - 0s 3ms/step - loss: 8.0574 - mae: 8.0574 - val_loss: 7.9205 - val_mae: 7.9205
# Epoch 32/100
# 136/136 [==============================] - 0s 3ms/step - loss: 8.0283 - mae: 8.0283 - val_loss: 7.8932 - val_mae: 7.8932
# Epoch 33/100
# 136/136 [==============================] - 0s 3ms/step - loss: 8.0029 - mae: 8.0029 - val_loss: 7.8697 - val_mae: 7.8697
# Epoch 34/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.9811 - mae: 7.9811 - val_loss: 7.8494 - val_mae: 7.8494
# Epoch 35/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.9622 - mae: 7.9622 - val_loss: 7.8316 - val_mae: 7.8316
# Epoch 36/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.9456 - mae: 7.9456 - val_loss: 7.8153 - val_mae: 7.8153
# Epoch 37/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.9309 - mae: 7.9309 - val_loss: 7.8009 - val_mae: 7.8009
# Epoch 38/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.9176 - mae: 7.9176 - val_loss: 7.7879 - val_mae: 7.7879
# Epoch 39/100
# 136/136 [==============================] - 0s 4ms/step - loss: 7.9053 - mae: 7.9053 - val_loss: 7.7758 - val_mae: 7.7758
# Epoch 40/100
# 136/136 [==============================] - 0s 4ms/step - loss: 7.8938 - mae: 7.8938 - val_loss: 7.7646 - val_mae: 7.7646
# Epoch 41/100
# 136/136 [==============================] - 1s 4ms/step - loss: 7.8827 - mae: 7.8827 - val_loss: 7.7543 - val_mae: 7.7543
# Epoch 42/100
# 136/136 [==============================] - 1s 5ms/step - loss: 7.8724 - mae: 7.8724 - val_loss: 7.7454 - val_mae: 7.7454
# Epoch 43/100
# 136/136 [==============================] - 1s 4ms/step - loss: 7.8626 - mae: 7.8626 - val_loss: 7.7368 - val_mae: 7.7368
# Epoch 44/100
# 136/136 [==============================] - 1s 4ms/step - loss: 7.8536 - mae: 7.8536 - val_loss: 7.7290 - val_mae: 7.7290
# Epoch 45/100
# 136/136 [==============================] - 1s 4ms/step - loss: 7.8450 - mae: 7.8450 - val_loss: 7.7217 - val_mae: 7.7217
# Epoch 46/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.8370 - mae: 7.8370 - val_loss: 7.7151 - val_mae: 7.7151
# Epoch 47/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.8295 - mae: 7.8295 - val_loss: 7.7086 - val_mae: 7.7086
# Epoch 48/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.8225 - mae: 7.8225 - val_loss: 7.7026 - val_mae: 7.7026
# Epoch 49/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.8156 - mae: 7.8156 - val_loss: 7.6969 - val_mae: 7.6969
# Epoch 50/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.8087 - mae: 7.8087 - val_loss: 7.6910 - val_mae: 7.6910
# Epoch 51/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.8020 - mae: 7.8020 - val_loss: 7.6858 - val_mae: 7.6858
# Epoch 52/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.7955 - mae: 7.7955 - val_loss: 7.6807 - val_mae: 7.6807
# Epoch 53/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.7894 - mae: 7.7894 - val_loss: 7.6756 - val_mae: 7.6756
# Epoch 54/100
# 136/136 [==============================] - 0s 2ms/step - loss: 7.7836 - mae: 7.7836 - val_loss: 7.6708 - val_mae: 7.6708
# Epoch 55/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.7779 - mae: 7.7779 - val_loss: 7.6662 - val_mae: 7.6662
# Epoch 56/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.7726 - mae: 7.7726 - val_loss: 7.6617 - val_mae: 7.6617
# Epoch 57/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.7672 - mae: 7.7672 - val_loss: 7.6572 - val_mae: 7.6572
# Epoch 58/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.7621 - mae: 7.7621 - val_loss: 7.6530 - val_mae: 7.6530
# Epoch 59/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.7570 - mae: 7.7570 - val_loss: 7.6489 - val_mae: 7.6489
# Epoch 60/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.7520 - mae: 7.7520 - val_loss: 7.6450 - val_mae: 7.6450
# Epoch 61/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.7472 - mae: 7.7472 - val_loss: 7.6414 - val_mae: 7.6414
# Epoch 62/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.7426 - mae: 7.7426 - val_loss: 7.6381 - val_mae: 7.6381
# Epoch 63/100
# 136/136 [==============================] - 0s 2ms/step - loss: 7.7380 - mae: 7.7380 - val_loss: 7.6348 - val_mae: 7.6348
# Epoch 64/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.7337 - mae: 7.7337 - val_loss: 7.6315 - val_mae: 7.6315
# Epoch 65/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.7293 - mae: 7.7293 - val_loss: 7.6286 - val_mae: 7.6286
# Epoch 66/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.7252 - mae: 7.7252 - val_loss: 7.6256 - val_mae: 7.6256
# Epoch 67/100
# 136/136 [==============================] - 0s 2ms/step - loss: 7.7211 - mae: 7.7211 - val_loss: 7.6228 - val_mae: 7.6228
# Epoch 68/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.7170 - mae: 7.7170 - val_loss: 7.6202 - val_mae: 7.6202
# Epoch 69/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.7130 - mae: 7.7130 - val_loss: 7.6174 - val_mae: 7.6174
# Epoch 70/100
# 136/136 [==============================] - 0s 2ms/step - loss: 7.7092 - mae: 7.7092 - val_loss: 7.6149 - val_mae: 7.6149
# Epoch 71/100
# 136/136 [==============================] - 0s 2ms/step - loss: 7.7056 - mae: 7.7056 - val_loss: 7.6125 - val_mae: 7.6125
# Epoch 72/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.7019 - mae: 7.7019 - val_loss: 7.6100 - val_mae: 7.6100
# Epoch 73/100
# 136/136 [==============================] - 1s 4ms/step - loss: 7.6982 - mae: 7.6982 - val_loss: 7.6077 - val_mae: 7.6077
# Epoch 74/100
# 136/136 [==============================] - 1s 4ms/step - loss: 7.6946 - mae: 7.6946 - val_loss: 7.6055 - val_mae: 7.6055
# Epoch 75/100
# 136/136 [==============================] - 1s 5ms/step - loss: 7.6910 - mae: 7.6910 - val_loss: 7.6031 - val_mae: 7.6031
# Epoch 76/100
# 136/136 [==============================] - 1s 4ms/step - loss: 7.6876 - mae: 7.6876 - val_loss: 7.6012 - val_mae: 7.6012
# Epoch 77/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.6842 - mae: 7.6842 - val_loss: 7.5992 - val_mae: 7.5992
# Epoch 78/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.6808 - mae: 7.6808 - val_loss: 7.5975 - val_mae: 7.5975
# Epoch 79/100
# 136/136 [==============================] - 0s 2ms/step - loss: 7.6776 - mae: 7.6776 - val_loss: 7.5957 - val_mae: 7.5957
# Epoch 80/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.6745 - mae: 7.6745 - val_loss: 7.5943 - val_mae: 7.5943
# Epoch 81/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.6714 - mae: 7.6714 - val_loss: 7.5926 - val_mae: 7.5926
# Epoch 82/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.6683 - mae: 7.6683 - val_loss: 7.5913 - val_mae: 7.5913
# Epoch 83/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.6652 - mae: 7.6652 - val_loss: 7.5897 - val_mae: 7.5897
# Epoch 84/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.6623 - mae: 7.6623 - val_loss: 7.5883 - val_mae: 7.5883
# Epoch 85/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.6594 - mae: 7.6594 - val_loss: 7.5869 - val_mae: 7.5869
# Epoch 86/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.6566 - mae: 7.6566 - val_loss: 7.5857 - val_mae: 7.5857
# Epoch 87/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.6537 - mae: 7.6537 - val_loss: 7.5844 - val_mae: 7.5844
# Epoch 88/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.6510 - mae: 7.6510 - val_loss: 7.5834 - val_mae: 7.5834
# Epoch 89/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.6482 - mae: 7.6482 - val_loss: 7.5820 - val_mae: 7.5820
# Epoch 90/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.6456 - mae: 7.6456 - val_loss: 7.5810 - val_mae: 7.5810
# Epoch 91/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.6430 - mae: 7.6430 - val_loss: 7.5799 - val_mae: 7.5799
# Epoch 92/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.6404 - mae: 7.6404 - val_loss: 7.5788 - val_mae: 7.5788
# Epoch 93/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.6378 - mae: 7.6378 - val_loss: 7.5776 - val_mae: 7.5776
# Epoch 94/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.6354 - mae: 7.6354 - val_loss: 7.5764 - val_mae: 7.5764
# Epoch 95/100
# 136/136 [==============================] - 0s 2ms/step - loss: 7.6328 - mae: 7.6328 - val_loss: 7.5755 - val_mae: 7.5755
# Epoch 96/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.6305 - mae: 7.6305 - val_loss: 7.5741 - val_mae: 7.5741
# Epoch 97/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.6280 - mae: 7.6280 - val_loss: 7.5732 - val_mae: 7.5732
# Epoch 98/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.6255 - mae: 7.6255 - val_loss: 7.5721 - val_mae: 7.5721
# Epoch 99/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.6229 - mae: 7.6229 - val_loss: 7.5708 - val_mae: 7.5708
# Epoch 100/100
# 136/136 [==============================] - 0s 3ms/step - loss: 7.6206 - mae: 7.6206 - val_loss: 7.5698 - val_mae: 7.5698
# Test MAE: [7.569819927215576, 7.569819927215576]
# 34/34 [==============================] - 0s 2ms/step
# Mean Absolute Error: 7.569819997776957
# Mean Squared Error: 89.53980761709305
# R-squared: 0.28163250122107264
# 34/34 [==============================] - 0s 1ms/step
# 136/136 [==============================] - 0s 3ms/step
# <ipython-input-16-69081458b4ec>:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   diff[index] = abs(y[index] - y_pred[index])
